# %%
#Name: Aashish Singh , Section: Q , Roll No.: 20

# %%
"""
Problem Statement: 10
You are given a dataset (salry_prediction.csv) containing 
years_of_experience as an input feature and salary as target. Implement a 
program to perform Simple Linear Regression and analyze the 
relationship between an input feature and a target variable and perform 
the following: 
i. Read the dataset into a dataframe and train a simple 
linear regression model after splitting the dataset into 
train and test data in the ratio of 70:30. 
ii. Determine the slope and intercept of the best fit line. 
iii. Plot the regression line along with actual data points. 
iv. Use the trained model to predict salary of new data 
points. 
v. Evaluate the performance of the model using 
appropriate regression metrics. 
"""

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#i.) Load dataset
df = pd.read_csv("salary_prediction.csv")

print(df.head())

# Define features and target
X = df[['years_of_experience']]
y = df['salary']

# Split dataset (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
# Out:
#    years_of_experience         salary
# 0             7.490802   67889.247230
# 1            19.014286  123576.393889
# 2            14.639879  103658.198064
# 3            11.973170   79928.003850
# 4             3.120373   44503.504605

# %%
#Train model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Slope and Intercept
slope = model.coef_[0]
intercept = model.intercept_

print("Slope (m):", slope)
print("Intercept (b):", intercept)
# Out:
# Slope (m): 4883.344744993216
# Intercept (b): 30589.502810494516

# %%
# Plot Regression Line

plt.figure()
plt.scatter(X, y)  # actual data
plt.plot(X, model.predict(X))  # regression line
plt.title("Salary vs Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
#iv.)  Predict new data
new_experience = pd.DataFrame({
    'years_of_experience': [5, 10, 15]
})

new_salary_pred = model.predict(new_experience)
print("Predicted salaries:", new_salary_pred)
# Out:
# Predicted salaries: [ 55006.22653546  79422.95026043 103839.67398539]

# %%
# v. Model Evaluation

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Performance:")
print("MAE:", mae)
print("MSE:", mse)
print("R2 Score:", r2)
# Out:
# Model Performance:
# MAE: 2986.697761065608
# MSE: 15773739.044461302
# R2 Score: 0.9854440134870828
